# %% [markdown]
# ## Data Collection & Preparation
#
# * ``Pandas`` for managing the data
# * ``NumPy`` for math operations
# * ``Sklearn`` for Machine Learning
# * ``Seaborn`` for advanced visualization
# * ``Matplotlib`` for additional plotting

# %%
# Import libraries 

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
# %matplotlib inline

# %%
#read data files

cs = pd.read_csv("charging_sessions.csv")
wba = pd.read_csv("weather_burbank_airport.csv")

# %%
#print the first 5 rows of the charging_sessions dataset
cs.head()
# Out:
#    Unnamed: 0                        id             connectionTime  \
# 0           0  5e23b149f9af8b5fe4b973cf  2020-01-02 13:08:54+00:00
# 1           1  5e23b149f9af8b5fe4b973d0  2020-01-02 13:36:50+00:00
# 2           2  5e23b149f9af8b5fe4b973d1  2020-01-02 13:56:35+00:00
# 3           3  5e23b149f9af8b5fe4b973d2  2020-01-02 13:59:58+00:00
# 4           4  5e23b149f9af8b5fe4b973d3  2020-01-02 14:00:01+00:00
#
#               disconnectTime           doneChargingTime  kWhDelivered  \
# 0  2020-01-02 19:11:15+00:00  2020-01-02 17:31:35+00:00        25.016
# 1  2020-01-02 22:38:21+00:00  2020-01-02 20:18:05+00:00        33.097
# 2  2020-01-03 00:39:22+00:00  2020-01-02 16:35:06+00:00         6.521
# 3  2020-01-02 16:38:39+00:00  2020-01-02 15:18:45+00:00         2.355
# 4  2020-01-02 22:08:40+00:00  2020-01-02 18:17:30+00:00        13.375
#
#                                 sessionID  siteID  spaceID    stationID  \
# 0  1_1_179_810_2020-01-02 13:08:53.870034       1  AG-3F30  1-1-179-810
# 1  1_1_193_825_2020-01-02 13:36:49.599853       1  AG-1F01  1-1-193-825
# 2  1_1_193_829_2020-01-02 13:56:35.214993       1  AG-1F03  1-1-193-829
# 3  1_1_193_820_2020-01-02 13:59:58.309319       1  AG-1F04  1-1-193-820
# 4  1_1_193_819_2020-01-02 14:00:00.779967       1  AG-1F06  1-1-193-819
#
#               timezone  userID  \
# 0  America/Los_Angeles   194.0
# 1  America/Los_Angeles  4275.0
# 2  America/Los_Angeles   344.0
# 3  America/Los_Angeles  1117.0
# 4  America/Los_Angeles   334.0
#
#                                           userInputs
# 0  [{'WhPerMile': 250, 'kWhRequested': 25.0, 'mil...
# 1  [{'WhPerMile': 280, 'kWhRequested': 70.0, 'mil...
# 2  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 3  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 4  [{'WhPerMile': 400, 'kWhRequested': 16.0, 'mil...

# %%
#print out the first 5 rows of the weather burbank airport dataset
wba.head()
# Out:
#       city            timestamp  temperature  cloud_cover  \
# 0  Burbank  2018-01-01 08:53:00          9.0         33.0
# 1  Burbank  2018-01-01 09:53:00          9.0         33.0
# 2  Burbank  2018-01-01 10:53:00          9.0         21.0
# 3  Burbank  2018-01-01 11:53:00          9.0         29.0
# 4  Burbank  2018-01-01 12:53:00          8.0         33.0
#
#   cloud_cover_description  pressure  windspeed  precipitation  \
# 0                    Fair    991.75        9.0            0.0
# 1                    Fair    992.08        0.0            0.0
# 2                    Haze    992.08        0.0            0.0
# 3           Partly Cloudy    992.08        0.0            0.0
# 4                    Fair    992.08        0.0            0.0
#
#    felt_temperature
# 0               8.0
# 1               9.0
# 2               9.0
# 3               9.0
# 4               8.0

# %%
#print out the columns of charging sessions dataset
cs.columns
# Out:
# Index(['Unnamed: 0', 'id', 'connectionTime', 'disconnectTime',
#        'doneChargingTime', 'kWhDelivered', 'sessionID', 'siteID', 'spaceID',
#        'stationID', 'timezone', 'userID', 'userInputs'],
#       dtype='object')

# %%
#print out the columns of weather burbank airport dataset
wba.columns
# Out:
# Index(['city', 'timestamp', 'temperature', 'cloud_cover',
#        'cloud_cover_description', 'pressure', 'windspeed', 'precipitation',
#        'felt_temperature'],
#       dtype='object')

# %%
#print out the tail of cs dataset to see how many entries there are
cs.tail()
# Out:
#        Unnamed: 0                        id             connectionTime  \
# 66445       10083  5d574ad2f9af8b4c10c03652  2019-07-31 18:08:04+00:00
# 66446       10084  5d574ad2f9af8b4c10c03653  2019-07-31 18:40:41+00:00
# 66447       10085  5d574ad2f9af8b4c10c03654  2019-07-31 19:04:40+00:00
# 66448       10086  5d574ad2f9af8b4c10c03655  2019-07-31 19:19:47+00:00
# 66449       10087  5d574ad2f9af8b4c10c03656  2019-07-31 19:21:47+00:00
#
#                   disconnectTime           doneChargingTime  kWhDelivered  \
# 66445  2019-07-31 23:29:18+00:00  2019-07-31 23:30:18+00:00        28.787
# 66446  2019-08-01 00:59:42+00:00  2019-07-31 21:44:23+00:00         7.787
# 66447  2019-07-31 22:44:22+00:00  2019-07-31 22:45:21+00:00        11.274
# 66448  2019-08-01 00:34:51+00:00  2019-07-31 21:25:30+00:00        11.589
# 66449  2019-07-31 22:00:04+00:00  2019-07-31 20:51:34+00:00         0.897
#
#                                     sessionID  siteID  spaceID    stationID  \
# 66445  1_1_179_809_2019-07-31 18:08:04.432654       1  AG-3F27  1-1-179-809
# 66446  1_1_179_810_2019-07-31 18:40:40.900203       1  AG-3F30  1-1-179-810
# 66447  1_1_191_795_2019-07-31 19:04:40.098273       1  AG-4F51  1-1-191-795
# 66448  1_1_191_778_2019-07-31 19:19:46.919358       1  AG-4F43  1-1-191-778
# 66449  1_1_178_817_2019-07-31 19:21:46.727697       1  AG-1F09  1-1-178-817
#
#                   timezone  userID  \
# 66445  America/Los_Angeles   393.0
# 66446  America/Los_Angeles   220.0
# 66447  America/Los_Angeles  1974.0
# 66448  America/Los_Angeles   942.0
# 66449  America/Los_Angeles     NaN
#
#                                               userInputs
# 66445  [{'WhPerMile': 240, 'kWhRequested': 31.2, 'mil...
# 66446  [{'WhPerMile': 333, 'kWhRequested': 6.66, 'mil...
# 66447  [{'WhPerMile': 333, 'kWhRequested': 19.98, 'mi...
# 66448  [{'WhPerMile': 275, 'kWhRequested': 22.0, 'mil...
# 66449                                                NaN

# %%
#print out the tail of cs dataset to see how many entries there are
wba.tail()
# Out:
#           city            timestamp  temperature  cloud_cover  \
# 29239  Burbank  2021-01-01 03:53:00         13.0         33.0
# 29240  Burbank  2021-01-01 04:53:00         12.0         33.0
# 29241  Burbank  2021-01-01 05:53:00         12.0         33.0
# 29242  Burbank  2021-01-01 06:53:00         11.0         33.0
# 29243  Burbank  2021-01-01 07:53:00         10.0         33.0
#
#       cloud_cover_description  pressure  windspeed  precipitation  \
# 29239                    Fair    986.81        0.0            0.0
# 29240                    Fair    986.81       11.0            0.0
# 29241                    Fair    987.47        9.0            0.0
# 29242                    Fair    987.14       13.0            0.0
# 29243                    Fair    987.80        6.0            0.0
#
#        felt_temperature
# 29239              13.0
# 29240              12.0
# 29241              12.0
# 29242              11.0
# 29243              10.0

# %% [markdown]
# ### We will focus on the charging_sessions dataset for a while

# %%
#print information about cs dataset
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66450 entries, 0 to 66449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        66450 non-null  int64
#  1   id                66450 non-null  object
#  2   connectionTime    66450 non-null  object
#  3   disconnectTime    66450 non-null  object
#  4   doneChargingTime  62362 non-null  object
#  5   kWhDelivered      66450 non-null  float64
#  6   sessionID         66450 non-null  object
#  7   siteID            66450 non-null  int64
#  8   spaceID           66450 non-null  object
#  9   stationID         66450 non-null  object
#  10  timezone          66450 non-null  object
#  11  userID            49187 non-null  float64
#  12  userInputs        49187 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.6+ MB

# %% [markdown]
# We can see that this dataset has an unnamed column that represents the entry number. For better readability, we will rename this column

# %%
#rename the unnamed column
cs.rename( columns={'Unnamed: 0':'number'}, inplace=True )

# %%
#check if the column was renamed
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66450 entries, 0 to 66449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   number            66450 non-null  int64
#  1   id                66450 non-null  object
#  2   connectionTime    66450 non-null  object
#  3   disconnectTime    66450 non-null  object
#  4   doneChargingTime  62362 non-null  object
#  5   kWhDelivered      66450 non-null  float64
#  6   sessionID         66450 non-null  object
#  7   siteID            66450 non-null  int64
#  8   spaceID           66450 non-null  object
#  9   stationID         66450 non-null  object
#  10  timezone          66450 non-null  object
#  11  userID            49187 non-null  float64
#  12  userInputs        49187 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.6+ MB

# %% [markdown]
# From looking at the count of every column, we can see that the "doneChargingTime" has missing values. The missing values in the "userID" and "userInputs" columns are because the user was not registered, so we can ignore them for now.

# %% [markdown]
# **Detecting missing numerical data**

# %%
#check if we can spot null-values
cs.isnull()
# Out:
#        number     id  connectionTime  disconnectTime  doneChargingTime  \
# 0       False  False           False           False             False
# 1       False  False           False           False             False
# 2       False  False           False           False             False
# 3       False  False           False           False             False
# 4       False  False           False           False             False
# ...       ...    ...             ...             ...               ...
# 66445   False  False           False           False             False
# 66446   False  False           False           False             False
# 66447   False  False           False           False             False
# 66448   False  False           False           False             False
# 66449   False  False           False           False             False
#
#        kWhDelivered  sessionID  siteID  spaceID  stationID  timezone  userID  \
# 0             False      False   False    False      False     False   False
# 1             False      False   False    False      False     False   False
# 2             False      False   False    False      False     False   False
# 3             False      False   False    False      False     False   False
# 4             False      False   False    False      False     False   False
# ...             ...        ...     ...      ...        ...       ...     ...
# 66445         False      False   False    False      False     False   False
# 66446         False      False   False    False      False     False   False
# 66447         False      False   False    False      False     False   False
# 66448         False      False   False    False      False     False   False
# 66449         False      False   False    False      False     False    True
#
#        userInputs
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 66445       False
# 66446       False
# 66447       False
# 66448       False
# 66449        True
#
# [66450 rows x 13 columns]

# %%
#drop all rows containing null values
cs.dropna(axis=0, inplace=False)
# Out:
#        number                        id             connectionTime  \
# 0           0  5e23b149f9af8b5fe4b973cf  2020-01-02 13:08:54+00:00
# 1           1  5e23b149f9af8b5fe4b973d0  2020-01-02 13:36:50+00:00
# 2           2  5e23b149f9af8b5fe4b973d1  2020-01-02 13:56:35+00:00
# 3           3  5e23b149f9af8b5fe4b973d2  2020-01-02 13:59:58+00:00
{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 4      [{'WhPerMile': 400, 'kWhRequested': 16.0, 'mil...
# ...                                                  ...
# 66444  [{'WhPerMile': 200, 'kWhRequested': 28.0, 'mil...
# 66445  [{'WhPerMile': 240, 'kWhRequested': 31.2, 'mil...
# 66446  [{'WhPerMile': 333, 'kWhRequested': 6.66, 'mil...
# 66447  [{'WhPerMile': 333, 'kWhRequested': 19.98, 'mi...
# 66448  [{'WhPerMile': 275, 'kWhRequested': 22.0, 'mil...
#
# [46008 rows x 13 columns]

# %%
#check how many rows are getting dropped
len(cs)-len(cs.dropna())
# Out:
# 20442

# %% [markdown]
# This number is higher than expected, but because this factors in the null values from userID and userInputs(unregistered users or users with no Input), we want so specifically look for missing values in the "doneChargingTime"-column

# %%
len(cs)-len(cs.dropna(subset = ['doneChargingTime']))
# Out:
# 4088

# %% [markdown]
# This number tells us that there are 4088 sessions with no timestamp for when the EV got done charging, meaning that it didn't fully charge. Let's look at this data.

# %%
#display records with 'doneCharging = Null
cs_notdone = cs[cs['doneChargingTime'].isnull()]
cs_notdone
# Out:
#        number                        id             connectionTime  \
# 3756     3756  5ea3848df9af8b428bf97225  2020-04-08 16:36:53+00:00
# 3757     3757  5ea4d60df9af8b46573f1ee7  2020-04-09 13:23:52+00:00
# 3758     3758  5ea4d60df9af8b46573f1ee8  2020-04-09 13:40:03+00:00
# 3759     3759  5ea4d60df9af8b46573f1ee9  2020-04-09 14:01:53+00:00
# 3760     3760  5ea4d60df9af8b46573f1eea  2020-04-09 15:01:06+00:00
# ...       ...                       ...                        ...
# 60411    4049  5cb3d2a8f9af8b4551261e75  2019-03-30 00:32:10+00:00
# 61097    4735  5cc8e891f9af8b45d975b819  2019-04-14 16:19:12+00:00
# 61103    4741  5cca3a54f9af8b49aaa4cbac  2019-04-15 13:00:59+00:00
# 61117    4755  5cca3a54f9af8b49aaa4cbba  2019-04-15 13:52:45+00:00
# 65530    9168  5d3f8f96f9af8b7f97666a55  2019-07-13 20:13:18+00:00
#
#                   disconnectTime doneChargingTime  kWhDelivered  \
# 3756   2020-04-09 03:43:29+00:00              NaN        25.183
# 3757   2020-04-09 17:59:02+00:00              NaN        14.136
# 3758   2020-04-09 21:43:22+00:00              NaN        14.203
# 3759   2020-04-09 16:33:40+00:00              NaN        13.041
# 3760   2020-04-09 23:38:08+00:00              NaN         5.797
# ...                          ...              ...           ...
# 60411  2019-03-30 02:23:14+00:00              NaN        11.148
# 61097  2019-04-14 20:38:39+00:00              NaN        11.678
# 61103  2019-04-15 13:55:25+00:00              NaN         3.343
# 61117  2019-04-15 14:47:01+00:00              NaN         4.558
# 65530  2019-07-13 20:37:40+00:00              NaN         2.218
#
#                                     sessionID  siteID  spaceID    stationID  \
# 3756   1_1_194_822_2020-04-08 16:36:53.316264       1  AG-1F12  1-1-194-822
# 3757   1_1_193_827_2020-04-09 13:23:51.689520       1  AG-1F02  1-1-193-827
# 3758   1_1_178_823_2020-04-09 13:39:55.115497       1  AG-1F08  1-1-178-823
# 3759   1_1_178_828_2020-04-09 14:01:53.467693       1  AG-1F10  1-1-178-828
# 3760   1_1_193_820_2020-04-09 15:01:06.343454       1  AG-1F04  1-1-193-820
# ...                                       ...     ...      ...          ...
# 60411  1_1_193_829_2019-03-30 00:32:10.128651       1  AG-1F03  1-1-193-829
# 61097  1_1_193_816_2019-04-14 16:19:11.864262       1  AG-1F05  1-1-193-816
# 61103  1_1_193_819_2019-04-15 13:00:58.722284       1  AG-1F06  1-1-193-819
# 61117  1_1_179_800_2019-04-15 13:52:44.693153       1  AG-3F32  1-1-179-800
# 65530  1_1_193_825_2019-07-13 20:13:18.490314       1  AG-1F01  1-1-193-825
#
#                   timezone  userID  \
# 3756   America/Los_Angeles   507.0
# 3757   America/Los_Angeles   419.0
# 3758   America/Los_Angeles  5065.0
# 3759   America/Los_Angeles   651.0
# 3760   America/Los_Angeles   466.0
# ...                    ...     ...
# 60411  America/Los_Angeles   194.0
# 61097  America/Los_Angeles   364.0
# 61103  America/Los_Angeles   651.0
# 61117  America/Los_Angeles   194.0
# 65530  America/Los_Angeles    76.0
#
#                                               userInputs
# 3756   [{'WhPerMile': 250, 'kWhRequested': 75.0, 'mil...
# 3757   [{'WhPerMile': 400, 'kWhRequested': 40.0, 'mil...
# 3758   [{'WhPerMile': 400, 'kWhRequested': 24.0, 'mil...
# 3759   [{'WhPerMile': 400, 'kWhRequested': 20.0, 'mil...
# 3760   [{'WhPerMile': 300, 'kWhRequested': 6.0, 'mile...
# ...                                                  ...
# 60411  [{'WhPerMile': 400, 'kWhRequested': 24.0, 'mil...
# 61097  [{'WhPerMile': 400, 'kWhRequested': 56.0, 'mil...
# 61103  [{'WhPerMile': 400, 'kWhRequested': 20.0, 'mil...
# 61117  [{'WhPerMile': 400, 'kWhRequested': 12.0, 'mil...
# 65530  [{'WhPerMile': 301, 'kWhRequested': 9.03, 'mil...
#
# [4088 rows x 13 columns]

# %% [markdown]
# ### Dealing with missing values
#
# When dealing with missing values, we can either **eliminate** them from the dataset or **impute** the null values with estimates. Because the missing data points are timestamps, it's hard them because they simply do not exist. The EV never got done charging, so estimating a value doesn't make any sense. And because our job is to optimize utilization, looking at data points where the EV never fully charged(and thus didn't stay plugged in without charging and taking up charging space) is not adequate. That is why we will drop these data points.

# %%
#we take every row where "doneChargingTime" is not null into our new dataset cs_clean
charging_sessions = cs[cs['doneChargingTime'].notna()]

# %%
charging_sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62362 entries, 0 to 66449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   number            62362 non-null  int64
#  1   id                62362 non-null  object
#  2   connectionTime    62362 non-null  object
#  3   disconnectTime    62362 non-null  object
#  4   doneChargingTime  62362 non-null  object
#  5   kWhDelivered      62362 non-null  float64
#  6   sessionID         62362 non-null  object
#  7   siteID            62362 non-null  int64
#  8   spaceID           62362 non-null  object
#  9   stationID         62362 non-null  object
#  10  timezone          62362 non-null  object
#  11  userID            46008 non-null  float64
#  12  userInputs        46008 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Quality Checks
# Now, we have to do some **quality checks** to ensure that our data does not have any errors and that the entries make sense. First, lets check station and spaceIDs.

# %%
charging_sessions['stationID'].nunique()
# Out:
# 106

# %%
charging_sessions['spaceID'].nunique()
# Out:
# 106

# %%
charging_sessions['stationID'].unique()
# Out:
# array(['1-1-179-810', '1-1-193-825', '1-1-193-829', '1-1-193-820',
#        'CA-493', 'CA-499', 'CA-323', 'CA-313', 'CA-324', 'CA-513',
#        'CA-305', 'CA-317', 'CA-510', 'CA-315', 'CA-321', 'CA-490',
#        'CA-497', 'CA-489', 'CA-319', 'CA-492', 'CA-494', 'CA-502',
#        'CA-500', 'CA-495', 'CA-498', 'CA-304', 'CA-307', 'CA-306',
#        'CA-501', 'CA-318', 'CA-308', 'CA-316', 'CA-312', 'CA-320',
#        'CA-212', 'CA-508', 'CA-322', 'CA-314', 'CA-503', 'CA-504',
#        'CA-496', 'CA-310', 'CA-506', 'CA-149', 'CA-509', 'CA-507',
#        'CA-511', 'CA-213', 'CA-505', 'CA-148'], dtype=object)

# %% [markdown]
# We see that both stationID and spaceID have 106 entries, so we will assume that they are mapped 1:1. spaceID most likely describes the parking space and stationID the charging station besides that parking space.

# %% [markdown]
# Now, lets turn timestamp data into the right datatypes

# %%
charging_sessions['connectionTime'] = pd.to_datetime(charging_sessions['connectionTime'])
charging_sessions['disconnectTime'] = pd.to_datetime(charging_sessions['disconnectTime'])
charging_sessions['doneChargingTime'] = pd.to_datetime(charging_sessions['doneChargingTime'])
# Out:
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\257518988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charging_sessions['connectionTime'] = pd.to_datetime(charging_sessions['connectionTime'])
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\257518988.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charging_sessions['disconnectTime'] = pd.to_datetime(charging_sessions['disconnectTime'])
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\257518988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charging_sessions['doneChargingTime'] = pd.to_datetime(charging_sessions['doneChargingTime'])

# %%
charging_sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62335 entries, 0 to 66449
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   number            62335 non-null  int64
#  1   id                62335 non-null  object
#  2   connectionTime    62335 non-null  datetime64[ns, UTC]
#  3   disconnectTime    62335 non-null  datetime64[ns, UTC]
#  4   doneChargingTime  62335 non-null  datetime64[ns, UTC]
#  5   kWhDelivered      62335 non-null  float64
#  6   sessionID         62335 non-null  object
#  7   siteID            62335 non-null  int64
#  8   spaceID           62335 non-null  object
#  9   stationID         62335 non-null  object
#  10  timezone          62335 non-null  object
# dtypes: datetime64[ns, UTC](3), float64(1), int64(2), object(5)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Logic checks
# Now we want to check if the data makes sense. For that, we will check three things. First, we will check if every **connectionTime** timestamp comes before the corresponding **disconnectTime** timestamp. An EV first has to connect to the station if it wants to disconnect from it. Second, we want to check if every **doneChargingTime** comes after every **connectionTime**, because an EV has to be still connected to be done charging. Lastly, we want to check if there are **doneChargingTime**s that come after **disconnectTime**. This would make no sense, because an unplugged EV can not be done charging after it got unplugged.

# %%
len(charging_sessions[charging_sessions['connectionTime']>charging_sessions['disconnectTime']])
# Out:
# 0

# %% [markdown]
# There are no entries where connectionTime comes before disconnectTime

# %%
len(charging_sessions[charging_sessions['connectionTime']>charging_sessions['doneChargingTime']])
# Out:
# 27

# %% [markdown]
# There are 27 entries where connectionTime comes after doneChargingTime. Lets further investigate.

# %%
charging_sessions[charging_sessions['connectionTime']>charging_sessions['doneChargingTime']]
# Out:
#        number                        id             connectionTime  \
# 42434   2_39_78_360_2018-10-12 15:59:07.388438       2   CA-322   2-39-78-360
# 42452   2_39_78_365_2018-10-12 18:40:37.245744       2   CA-321   2-39-78-365
# 42618   2_39_78_360_2018-10-15 15:42:13.677037       2   CA-322   2-39-78-360
# 43484   2_39_78_365_2018-10-26 20:27:53.015524       2   CA-321   2-39-78-365
# 44040   2_39_78_364_2018-11-04 02:10:08.418061       2   CA-495   2-39-78-364
# 44041   2_39_129_17_2018-11-04 03:56:16.817298       2   CA-307   2-39-129-17
# 44042   2_39_139_28_2018-11-04 04:33:18.910858       2   CA-303   2-39-139-28
# 44199   2_39_78_360_2018-11-07 03:40:06.365714       2   CA-322   2-39-78-360
# 51110   2_39_78_366_2020-03-12 20:20:14.592808       2   CA-323   2-39-78-366
# 62146   1_1_191_789_2019-05-03 18:35:38.365680       1  AG-4F52   1-1-191-789
#
#                   timezone  userID  \
# 22219  America/Los_Angeles     NaN
# 22253  America/Los_Angeles     NaN
# 23562  America/Los_Angeles  1154.0
# 23586  America/Los_Angeles  1154.0
# 27689  America/Los_Angeles     NaN
# 27740  America/Los_Angeles     NaN
# 29295  America/Los_Angeles  1470.0
# 31285  America/Los_Angeles     NaN
# 31287  America/Los_Angeles     NaN
# 31403  America/Los_Angeles     NaN
# 35840  America/Los_Angeles     NaN
# 38884  America/Los_Angeles     NaN
# 39875  America/Los_Angeles     NaN
# 41263  America/Los_Angeles     NaN
# 42102  America/Los_Angeles     NaN
# 42342  America/Los_Angeles     NaN
# 42347  America/Los_Angeles     NaN
# 42434  America/Los_Angeles     NaN
# 42452  America/Los_Angeles     NaN
# 42618  America/Los_Angeles     NaN
# 43484  America/Los_Angeles     NaN
# 44040  America/Los_Angeles     NaN
# 44041  America/Los_Angeles     NaN
# 44042  America/Los_Angeles   516.0
# 44199  America/Los_Angeles     NaN
# 51110  America/Los_Angeles   560.0
# 62146  America/Los_Angeles   483.0
#
#                                               userInputs
# 22219                                                NaN
# 22253                                                NaN
# 23562  [{'WhPerMile': 308, 'kWhRequested': 9.24, 'mil...
# 23586  [{'WhPerMile': 308, 'kWhRequested': 6.16, 'mil...
# 27689                                                NaN
# 27740                                                NaN
# 29295  [{'WhPerMile': 292, 'kWhRequested': 14.6, 'mil...
# 31285                                                NaN
# 31287                                                NaN
# 31403                                                NaN
# 35840                                                NaN
# 38884                                                NaN
# 39875                                                NaN
# 41263                                                NaN
# 42102                                                NaN
# 42342                                                NaN
# 42347                                                NaN
# 42434                                                NaN
# 42452                                                NaN
# 42618                                                NaN
# 43484                                                NaN
# 44040                                                NaN
# 44041                                                NaN
# 44042  [{'WhPerMile': 250, 'kWhRequested': 12.5, 'mil...
# 44199                                                NaN
# 51110  [{'WhPerMile': 400, 'kWhRequested': 32.0, 'mil...
# 62146  [{'WhPerMile': 350, 'kWhRequested': 7.0, 'mile...

# %% [markdown]
# If we take a closer look at these datapoints, we can see that for every datapoint where connectionTime > doneChargingTime holds true, the doneChargingTime occured round about a minute before the connectionTime. This can either be the system telling us that the EV was already full, or this could simply be an erroneous entry. Either way, only 27 entires are affected, so we decided to drop the entries.

# %%
charging_sessions.drop(charging_sessions[charging_sessions['connectionTime']>charging_sessions['doneChargingTime']].index,inplace=True)
# Out:
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\3982660818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charging_sessions.drop(charging_sessions[charging_sessions['connectionTime']>charging_sessions['doneChargingTime']].index,inplace=True)

# %%
len(charging_sessions[charging_sessions['connectionTime']>charging_sessions['doneChargingTime']])
# Out:
# 0

# %% [markdown]
# We succesfully got rid of these entries. Now lets check for the third requirement.

# %%
len(charging_sessions[charging_sessions['doneChargingTime']>charging_sessions['disconnectTime']])
# Out:
# 4692

# %% [markdown]
# Almost 4700 entries, which is quite a lot. We can not simply delete these sessions, so lets further investigate.

# %%
charging_sessions[charging_sessions['doneChargingTime']>charging_sessions['disconnectTime']]
# Out:
#        number                        id             connectionTime  \
# 12         12  5e23b149f9af8b5fe4b973db  2020-01-02 15:04:38+00:00
# 20         20  5e23b149f9af8b5fe4b973e3  2020-01-02 15:28:47+00:00
# 25         25  5e23b149f9af8b5fe4b973e8  2020-01-02 15:42:05+00:00
# 26         26  5e23b149f9af8b5fe4b973e9  2020-01-02 15:57:24+00:00
# 33         33  5e23b149f9af8b5fe4b973f0  2020-01-02 16:34:35+00:00
# ...       ...                       ...                        ...
# 66432   10070  5d574ad2f9af8b4c10c03645  2019-07-31 14:36:02+00:00
# 66439   10077  5d574ad2f9af8b4c10c0364c  2019-07-31 14:45:02+00:00
# 66440   10078  5d574ad2f9af8b4c10c0364d  2019-07-31 14:45:29+00:00
# 66445   10083  5d574ad2f9af8b4c10c03652  2019-07-31 18:08:04+00:00
# 66447   10085  5d574ad2f9af8b4c10c03654  2019-07-31 19:04:40+00:00
#
#                   disconnectTime           doneChargingTime  kWhDelivered  \
# 12     2020-01-02 22:08:39+00:00  2020-01-02 22:09:36+00:00        25.567
# 20     2020-01-02 19:01:54+00:00  2020-01-02 19:02:51+00:00         7.417
# 25     2020-01-02 21:58:45+00:00  2020-01-02 21:59:42+00:00        36.701
# 26     2020-01-02 16:35:37+00:00  2020-01-02 16:36:34+00:00         3.689
# 33     2020-01-02 18:49:41+00:00  2020-01-02 18:50:38+00:00         7.120
# ...                          ...                        ...           ...
# 66432  2019-07-31 22:34:10+00:00  2019-07-31 22:35:10+00:00         9.459
# 66439  2019-07-31 23:43:20+00:00  2019-07-31 23:44:19+00:00         8.289
# 66440  2019-07-31 22:01:32+00:00  2019-07-31 22:02:32+00:00        31.376
# 66445  2019-07-31 23:29:18+00:00  2019-07-31 23:30:18+00:00        28.787
# 66447  2019-07-31 22:44:22+00:00  2019-07-31 22:45:21+00:00        11.274
#
#                                     sessionID  siteID  spaceID    stationID  \
# 12     1_1_178_824_2020-01-02 15:04:38.051735       1  AG-1F07  1-1-178-824
# 20     1_1_193_827_2020-01-02 15:28:46.685366       1  AG-1F02  1-1-193-827
# 25     1_1_179_797_2020-01-02 15:42:05.217965       1  AG-3F23  1-1-179-797
# 26     1_1_179_781_2020-01-02 15:57:23.951170       1  AG-3F31  1-1-179-781
# 33     1_1_179_790_2020-01-02 16:34:34.999200       1  AG-3F19  1-1-179-790
# ...                                       ...     ...      ...          ...
# 66432  1_1_191_803_2019-07-31 14:36:02.181346       1  AG-4F49  1-1-191-803
# 66439  1_1_191_804_2019-07-31 14:45:01.555937       1  AG-4F34  1-1-191-804
# 66440  1_1_191_811_2019-07-31 14:45:29.388046       1  AG-4F42  1-1-191-811
# 66445  1_1_179_809_2019-07-31 18:08:04.432654       1  AG-3F27  1-1-179-809
# 66447  1_1_191_795_2019-07-31 19:04:40.098273       1  AG-4F51  1-1-191-795
#
#                   timezone  userID  \
# 12     America/Los_Angeles   528.0
# 20     America/Los_Angeles  1283.0
# 25     America/Los_Angeles   474.0
# 26     America/Los_Angeles   724.0
# 33     America/Los_Angeles  2276.0
# ...                    ...     ...
# 66432  America/Los_Angeles   826.0
# 66439  America/Los_Angeles   572.0
# 66440  America/Los_Angeles  1626.0
# 66445  America/Los_Angeles   393.0
# 66447  America/Los_Angeles  1974.0
#
#                                               userInputs
# 12     [{'WhPerMile': 250, 'kWhRequested': 50.0, 'mil...
# 20     [{'WhPerMile': 350, 'kWhRequested': 42.0, 'mil...
# 25     [{'WhPerMile': 400, 'kWhRequested': 32.0, 'mil...
# 26     [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 33     [{'WhPerMile': 600, 'kWhRequested': 18.0, 'mil...
# ...                                                  ...
# 66432  [{'WhPerMile': 250, 'kWhRequested': 35.0, 'mil...
# 66439  [{'WhPerMile': 231, 'kWhRequested': 9.24, 'mil...
# 66440  [{'WhPerMile': 200, 'kWhRequested': 38.0, 'mil...
# 66445  [{'WhPerMile': 240, 'kWhRequested': 31.2, 'mil...
# 66447  [{'WhPerMile': 333, 'kWhRequested': 19.98, 'mi...
#
# [4692 rows x 13 columns]

# %% [markdown]
# It becomes pretty apparent that the doneChargingTime also lies within a minute of the disconnectTime. This could mean that the station always delivers electricity for approx. another minute before it stops supplying energy. We will keep those entries, because discarding them would make us lose too many data points.

# %%
charging_sessions.nunique()
# Out:
# number              15277
# id                  60923
# connectionTime      60734
# disconnectTime      60801
# doneChargingTime    60610
# kWhDelivered        24656
# sessionID           60923
# siteID                  2
# spaceID               106
# stationID             106
# timezone                1
# userID                888
# userInputs          44638
# dtype: int64

# %% [markdown]
# ### Handle userInput and userID
# Working with the userInput and userID columns can be problematic. According to the task manual, they can change overtime. The amount of miles and Kwh request per user can change, which results in multiple userInputs per row. The data is complex to preprocess. And for the given task, we have not thought of a way on how we are going to use this data yet. This may change in the future, but as of now, we will ignore these columns, so we drop them.

# %%
charging_sessions.drop(columns=['userID', 'userInputs'],inplace=True)
# Out:
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\862065095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charging_sessions.drop(columns=['userID', 'userInputs'],inplace=True)

# %%
charging_sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62335 entries, 0 to 66449
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   number            62335 non-null  int64
#  1   id                62335 non-null  object
#  2   connectionTime    62335 non-null  object
#  3   disconnectTime    62335 non-null  object
#  4   doneChargingTime  62335 non-null  object
#  5   kWhDelivered      62335 non-null  float64
#  6   sessionID         62335 non-null  object
#  7   siteID            62335 non-null  int64
#  8   spaceID           62335 non-null  object
#  9   stationID         62335 non-null  object
#  10  timezone          62335 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Outliers
# Last thing we need to do, is delete outlier data form our dataset. An outlier is a data point that differs significantly from other observations. In our case, it would be a session which was too long, lets say more than 20 hours. Lets look for these sessions. To do that, we need to first figure out the length of the session. We will handle outliers in 02_Descriptive Analytics.

# %% [markdown]
# ## Weather data preparation

# %% [markdown]
# We first have to think of a way we want to utilize the weather data and manipulate the dataframe based on our plan.

# %%
wba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29244 entries, 0 to 29243
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city                     29244 non-null  object
#  1   timestamp                29244 non-null  object
#  2   temperature              29219 non-null  float64
#  3   cloud_cover              29224 non-null  float64
#  4   cloud_cover_description  29224 non-null  object
#  5   pressure                 29236 non-null  float64
#  6   windspeed                29158 non-null  float64
#  7   precipitation            29244 non-null  float64
#  8   felt_temperature         29218 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# We change the timestamp column to the timedate datatype.

# %%
wba['timestamp'] = pd.to_datetime(wba['timestamp'])

# %%
wba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29244 entries, 0 to 29243
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city                     29244 non-null  object
#  1   timestamp                29244 non-null  datetime64[ns]
#  2   temperature              29219 non-null  float64
#  3   cloud_cover              29224 non-null  float64
#  4   cloud_cover_description  29224 non-null  object
#  5   pressure                 29236 non-null  float64
#  6   windspeed                29158 non-null  float64
#  7   precipitation            29244 non-null  float64
#  8   felt_temperature         29218 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# Lets further investigate the columns, so see which ones will be interesting for us.

# %%
wba.describe(include = "all")
# Out:
#            city            timestamp   temperature   cloud_cover  \
# count     29244                29244  29219.000000  29224.000000
# unique        1                29244           NaN           NaN
# top     Burbank  2018-01-01 08:53:00           NaN           NaN
# freq      29244                    1           NaN           NaN
# mean        NaN                  NaN     17.885622     30.107993
# std         NaN                  NaN      6.454604      5.400388
# min         NaN                  NaN      2.000000      4.000000
# 25%         NaN                  NaN     13.000000     26.000000
# 50%         NaN                  NaN     17.000000     33.000000
# 75%         NaN                  NaN     22.000000     34.000000
# max         NaN                  NaN     46.000000     47.000000
#
#        cloud_cover_description      pressure     windspeed  precipitation  \
# count                    29224  29236.000000  29158.000000   29244.000000
# unique                      23           NaN           NaN            NaN
# top                       Fair           NaN           NaN            NaN
# freq                     17122           NaN           NaN            NaN
# mean                       NaN    986.879400      8.566568       0.059360
# std                        NaN      3.607065      6.699889       0.471682
# min                        NaN    971.000000      0.000000       0.000000
# 25%                        NaN    984.500000      6.000000       0.000000
# 50%                        NaN    986.480000      7.000000       0.000000
# 75%                        NaN    989.110000     13.000000       0.000000
# max                        NaN    999.650000     57.000000      18.540000
#
#         felt_temperature
# count       29218.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean           17.731433
# std             6.321100
# min             0.000000
# 25%            13.000000
# 50%            17.000000
# 75%            22.000000
# max            42.000000

# %% [markdown]
# The describe.(include ="all") function gives us a good look on all the variables. Based on this, we can see what columns we can drop and what columns might help us for the prediction model part. For now, we will keep the temperature variable and the percipation.

# %%
wba.cloud_cover_description.unique()
# Out:
# array(['Fair', 'Haze', 'Partly Cloudy', 'Mostly Cloudy', 'Cloudy', 'Fog',
#        'Light Rain', 'Rain', 'Heavy Rain', 'Heavy Rain / Windy',
#        'Light Rain / Windy', 'T-Storm', 'Fair / Windy', 'Cloudy / Windy',
#        'Mostly Cloudy / Windy', 'Partly Cloudy / Windy',
#        'Thunder in the Vicinity', 'Thunder', nan, 'Smoke',
#        'Light Rain with Thunder', 'Heavy T-Storm', 'Rain / Windy',
#        'Blowing Dust'], dtype=object)

# %% [markdown]
# The cloud cover description might also come in handy, so we will keep this column also.

# %% [markdown]
# We now want to look at from when to when the weather data is. For that, we first need to sort the dataframe, then look at the tail.

# %%
wba.sort_values(by='timestamp',inplace=True)

wba.head()
# Out:
#       city           timestamp  temperature  cloud_cover  \
# 0  Burbank 2018-01-01 08:53:00          9.0         33.0
# 1  Burbank 2018-01-01 09:53:00          9.0         33.0
# 2  Burbank 2018-01-01 10:53:00          9.0         21.0
# 3  Burbank 2018-01-01 11:53:00          9.0         29.0
# 4  Burbank 2018-01-01 12:53:00          8.0         33.0
#
#   cloud_cover_description  pressure  windspeed  precipitation  \
# 0                    Fair    991.75        9.0            0.0
# 1                    Fair    992.08        0.0            0.0
# 2                    Haze    992.08        0.0            0.0
# 3           Partly Cloudy    992.08        0.0            0.0
# 4                    Fair    992.08        0.0            0.0
#
#    felt_temperature
# 0               8.0
# 1               9.0
# 2               9.0
# 3               9.0
# 4               8.0

# %%
wba.tail()
# Out:
#           city           timestamp  temperature  cloud_cover  \
# 29239  Burbank 2021-01-01 03:53:00         13.0         33.0
# 29240  Burbank 2021-01-01 04:53:00         12.0         33.0
# 29241  Burbank 2021-01-01 05:53:00         12.0         33.0
# 29242  Burbank 2021-01-01 06:53:00         11.0         33.0
# 29243  Burbank 2021-01-01 07:53:00         10.0         33.0
#
#       cloud_cover_description  pressure  windspeed  precipitation  \
# 29239                    Fair    986.81        0.0            0.0
# 29240                    Fair    986.81       11.0            0.0
# 29241                    Fair    987.47        9.0            0.0
# 29242                    Fair    987.14       13.0            0.0
# 29243                    Fair    987.80        6.0            0.0
#
#        felt_temperature
# 29239              13.0
# 29240              12.0
# 29241              12.0
# 29242              11.0
# 29243              10.0

# %% [markdown]
# The dataframe has records from the first of January 2018 to the first of January 2021.

# %%
charging_sessions_sorted= charging_sessions.sort_values(by='connectionTime')

# %%
charging_sessions_sorted.tail()
# Out:
#        number                        id            connectionTime  \
# 49115    3030  61550519f9af8b76960e169b 2021-09-13 21:17:04+00:00
# 20176    5873  6155053bf9af8b76960e16cf 2021-09-13 21:37:59+00:00
# 49117    3032  61550519f9af8b76960e169d 2021-09-13 23:11:12+00:00
# 20177    5874  6155053bf9af8b76960e16d0 2021-09-14 01:08:16+00:00
# 20178    5875  6155053bf9af8b76960e16d1 2021-09-14 05:43:39+00:00
#
#                  disconnectTime          doneChargingTime  kWhDelivered  \
# 49115 2021-09-14 01:01:49+00:00 2021-09-13 23:18:07+00:00         6.715
# 20176 2021-09-14 00:12:49+00:00 2021-09-14 00:12:36+00:00         8.547
# 49117 2021-09-14 01:43:11+00:00 2021-09-14 00:13:35+00:00         2.018
# 20177 2021-09-14 01:31:24+00:00 2021-09-14 01:31:19+00:00         1.253
# 20178 2021-09-14 14:46:28+00:00 2021-09-14 14:46:22+00:00        53.937
#
#                                     sessionID  siteID  spaceID    stationID  \
# 49115  2_39_123_23_2021-09-13 21:16:44.026068       2   CA-313  2-39-123-23
# 20176  1_1_178_824_2021-09-13 21:37:44.554924       1  AG-1F07  1-1-178-824
# 49117  2_39_91_437_2021-09-13 23:10:59.528292       2   CA-317  2-39-91-437
# 20177  1_1_179_783_2021-09-14 01:08:03.220292       1  AG-3F29  1-1-179-783
# 20178  1_1_178_817_2021-09-14 05:43:27.354300       1  AG-1F09  1-1-178-817
#
#                   timezone
# 49115  America/Los_Angeles
# 20176  America/Los_Angeles
# 49117  America/Los_Angeles
# 20177  America/Los_Angeles
# 20178  America/Los_Angeles

# %%
charging_sessions_sorted.head()
# Out:
#        number                        id            connectionTime  \
# 30793       0  5bc90cb9f9af8b0d7fe77cd2 2018-04-25 11:08:04+00:00
# 30794       1  5bc90cb9f9af8b0d7fe77cd3 2018-04-25 13:45:10+00:00
# 30795       2  5bc90cb9f9af8b0d7fe77cd4 2018-04-25 13:45:50+00:00
# 30796       3  5bc90cb9f9af8b0d7fe77cd5 2018-04-25 14:37:06+00:00
# 30797       4  5bc90cb9f9af8b0d7fe77cd6 2018-04-25 14:40:34+00:00
#
#                  disconnectTime          doneChargingTime  kWhDelivered  \
# 30793 2018-04-25 13:20:10+00:00 2018-04-25 13:21:10+00:00         7.932
# 30794 2018-04-26 00:56:16+00:00 2018-04-25 16:44:15+00:00        10.013
# 30795 2018-04-25 23:04:45+00:00 2018-04-25 14:51:44+00:00         5.257
# 30796 2018-04-25 23:55:34+00:00 2018-04-25 16:05:22+00:00         5.177
# 30797 2018-04-25 23:03:12+00:00 2018-04-25 17:40:30+00:00        10.119
#
#                                     sessionID  siteID spaceID    stationID  \
# 30793  2_39_78_362_2018-04-25 11:08:04.400812       2  CA-496  2-39-78-362
# 30794   2_39_95_27_2018-04-25 13:45:09.617470       2  CA-319   2-39-95-27
# 30795  2_39_79_380_2018-04-25 13:45:49.962001       2  CA-489  2-39-79-380
# 30796  2_39_79_379_2018-04-25 14:37:06.460772       2  CA-327  2-39-79-379
# 30797  2_39_79_381_2018-04-25 14:40:33.638896       2  CA-490  2-39-79-381
#
#                   timezone
# 30793  America/Los_Angeles
# 30794  America/Los_Angeles
# 30795  America/Los_Angeles
# 30796  America/Los_Angeles
# 30797  America/Los_Angeles

# %% [markdown]
# We can see that the weather data does not quite reach the charging session dates. That means, we have weather data up until **January 2021**, but charging sessions till **September 2021**. Also, the charging session data starts at the 25th of April 2018. We will have to truncate the data such that the charging session daterange and the weather dateranges match(25-04-2018 till 01-01-2021).

# %%
all_hours = pd.date_range(start='2018-04-25', end='2021-01-01', freq='H')
full_df = pd.DataFrame({'timestamp': all_hours})

# %%
weather_range = pd.merge_asof(full_df, wba, on='timestamp', direction='backward', suffixes=('_new', '_original'))

# %%
weather_range
# Out:
#                 timestamp     city  temperature  cloud_cover  \
# 0     2018-04-25 00:00:00  Burbank         24.0         34.0
# 1     2018-04-25 01:00:00  Burbank         24.0         30.0
# 2     2018-04-25 02:00:00  Burbank         21.0         30.0
# 3     2018-04-25 03:00:00  Burbank         19.0         29.0
# 4     2018-04-25 04:00:00  Burbank         18.0         29.0
# ...                   ...      ...          ...          ...
# 23564 2020-12-31 20:00:00  Burbank         17.0         34.0
# 23565 2020-12-31 21:00:00  Burbank         18.0         34.0
# 23566 2020-12-31 22:00:00  Burbank         19.0         34.0
# 23567 2020-12-31 23:00:00  Burbank         18.0         34.0
# 23568 2021-01-01 00:00:00  Burbank         16.0         34.0
#
#       cloud_cover_description  pressure  windspeed  precipitation  \
# 0                        Fair    986.81       15.0            0.0
# 1               Partly Cloudy    986.48       17.0            0.0
# 2               Partly Cloudy    986.81       13.0            0.0
# 3               Partly Cloudy    987.14       11.0            0.0
# 4               Partly Cloudy    987.47        7.0            0.0
# ...                       ...       ...        ...            ...
# 23564                    Fair    985.82       19.0            0.0
# 23565                    Fair    984.50       26.0            0.0
# 23566                    Fair    985.16       19.0            0.0
# 23567                    Fair    984.83       31.0            0.0
# 23568                    Fair    985.16       20.0            0.0
#
#        felt_temperature
# 0                  24.0
# 1                  24.0
# 2                  21.0
# 3                  19.0
# 4                  18.0
# ...                 ...
# 23564              17.0
# 23565              18.0
# 23566              19.0
# 23567              18.0
# 23568              16.0
#
# [23569 rows x 9 columns]

# %%
weather_range['temperature'].fillna(method='ffill', inplace=True)
weather_range['precipitation'].fillna(method='ffill', inplace=True)
weather_range['cloud_cover_description'].fillna(method='ffill', inplace=True)
weather_range.drop(columns='city',inplace=True)
weather_range.drop(columns='cloud_cover',inplace=True)
weather_range.drop(columns='pressure',inplace=True)
weather_range.drop(columns='windspeed',inplace=True)
weather_range.drop(columns='felt_temperature',inplace=True)
weather_range.head(1000)
# Out:
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\2218601444.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_range['temperature'].fillna(method='ffill', inplace=True)
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\2218601444.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_range['precipitation'].fillna(method='ffill', inplace=True)
# C:\Users\Göktug\AppData\Local\Temp\ipykernel_7640\2218601444.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   weather_range['cloud_cover_description'].fillna(method='ffill', inplace=True)
#               timestamp  temperature cloud_cover_description  precipitation
# 0   2018-04-25 00:00:00         24.0                    Fair            0.0
# 1   2018-04-25 01:00:00         24.0           Partly Cloudy            0.0
# 2   2018-04-25 02:00:00         21.0           Partly Cloudy            0.0
# 3   2018-04-25 03:00:00         19.0           Partly Cloudy            0.0
# 4   2018-04-25 04:00:00         18.0           Partly Cloudy            0.0
# ..                  ...          ...                     ...            ...
# 995 2018-06-05 11:00:00         16.0                  Cloudy            0.0
# 996 2018-06-05 12:00:00         16.0                  Cloudy            0.0
# 997 2018-06-05 13:00:00         16.0                  Cloudy            0.0
# 998 2018-06-05 14:00:00         16.0                  Cloudy            0.0
# 999 2018-06-05 15:00:00         16.0                  Cloudy            0.0
#
# [1000 rows x 4 columns]

# %%
weather_range.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23569 entries, 0 to 23568
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                23569 non-null  datetime64[ns]
#  1   temperature              23569 non-null  float64
#  2   cloud_cover_description  23569 non-null  object
#  3   precipitation            23569 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 736.7+ KB
